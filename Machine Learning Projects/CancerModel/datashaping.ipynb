# %%
import os
import pandas as pd
import numpy as np

# %%
#unzipping
# from zipfile import ZipFile

# with ZipFile('data-3.zip', 'r') as f:
#     f.extractall()

# %%
cd = '/home/DAVIDSON/iarolls/Workspace/CSC371/HW3/data-3'
df = pd.DataFrame(columns = ['cancer_type', 'patient_id'])
dictionary = {'cancer_type':[],
              'patient_id': []
             }
id_dict = {'Breast Invasive Carcinoma': 0, 'Kidney Renal Clear Cell Carcinoma': 1, 'Lung Adenocarcinoma': 2, 'Lung Squamous Cell Carcinoma': 3, 'Pancreatic Adenocarcinoma': 4, 'Uveal Melanoma': 5}
cancer = 0


for cancerType in os.listdir(cd):
    cancer = id_dict[cancerType]
    newpath = os.path.join(cd, cancerType)
    for foldername in os.listdir(newpath):
        folder = os.path.join(newpath, foldername)
        if os.path.isdir(folder):
            for filename in os.listdir(folder):
                if filename=='annotations.txt' or filename=='MANIFEST-checkpoint.txt':
                    continue
                file = os.path.join(folder, filename)
                if os.path.isdir(file):
                    continue
                dictionary['patient_id'].append(foldername)
                dictionary['cancer_type'].append(cancer)
                df_ex = pd.read_csv(file, sep='\t', lineterminator='\n')
                for item in df_ex.index:
                    key = df_ex['miRNA_ID'][item]
                    if key not in dictionary.keys():
                        dictionary[key] = []
                    dictionary[key].append(df_ex['reads_per_million_miRNA_mapped'][item])


dataframe = pd.DataFrame.from_dict(dictionary)                
dataframe.head()
# Out:
#    cancer_type                            patient_id  hsa-let-7a-1  \
# 0            3  f3955416-62ea-4500-98c8-011441b35d43   8754.387572
# 1            3  334b97fa-a326-434e-897d-b7a585d8b5cd   4113.019089
# 2            3  c0436c51-a79b-45a4-8971-83e42bd576e5   4470.362474
# 3            3  b0803e12-71fe-47e5-8b5b-3f715279dffe   9805.052537
# 4            3  8fed594c-e1f9-46ee-a12c-c50d73f9094a   6060.484631
#
#    hsa-let-7a-2  hsa-let-7a-3    hsa-let-7b   hsa-let-7c   hsa-let-7d  \
# 0   8612.668274   8657.045024  17740.679451  1505.230730   979.867271
# 1   4112.104576   4086.955488  12163.928160  1481.509933  1002.305486
# 2   4372.197259   4494.790684   8558.921069   290.424277   715.656085
# 3   9750.713643   9878.543664  11981.948798   480.587430   374.804747
# 4   6088.226693   6116.739368  12658.086407   568.326965   578.730238
#
#     hsa-let-7e  hsa-let-7f-1  ...  hsa-mir-941-5  hsa-mir-942  hsa-mir-943  \
# ...

# %%
dataframe.to_csv('/home/DAVIDSON/iarolls/Workspace/CSC371/HW3/cancerDataframe.csv', index = False)
